# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# !python run_multi-task_rnn.py --data_dir data/ATIS_samples \
      --train_dir model_tmp\
      --max_sequence_length 50 \
      --task "joint" \
      --bidirectional_rnn True \
      --use_attention True
# Out:
# WARNING:tensorflow:From run_multi-task_rnn.py:460: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Applying Parameters:
# Preparing data in data/ATIS_samples
# {'_PAD': 0, '_UNK': 1, 'to': 2, 'from': 3, 'the': 4, 'boston': 5, 'on': 6, 'round': 7, 'trip': 8, 'atlanta': 9, "what's": 10, 'lowest': 11, 'fare': 12, 'dallas': 13, 'find': 14, 'me': 15, 'earliest': 16, 'flight': 17, 'any': 18, 'day': 19, 'of': 20, 'week': 21, 'display': 22, 'all': 23, 'flights': 24, 'baltimore': 25, 'july': 26, 'thirty': 27, 'first': 28, 'economy': 29, 'fares': 30, 'new': 31, 'york': 32, 'miami': 33, 'i': 34, 'need': 35, 'fly': 36, 'denver': 37, 'san': 38, 'francisco': 39, 'and': 40, 'back': 41}
# {'_PAD': 0, '_UNK': 1, 'O': 2, 'B-toloc.city_name': 3, 'B-fromloc.city_name': 4, 'B-round_trip': 5, 'I-round_trip': 6, 'B-cost_relative': 7, 'B-flight_mod': 8, 'B-depart_date.month_name': 9, 'B-depart_date.day_number': 10, 'I-depart_date.day_number': 11, 'B-economy': 12, 'I-fromloc.city_name': 13, 'I-toloc.city_name': 14}
# {'_UNK': 0, 'airfare': 1, 'flight': 2}
# WARNING:tensorflow:From run_multi-task_rnn.py:264: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1129 09:20:59.671023 140491425031936 module_wrapper.py:139] From run_multi-task_rnn.py:264: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From run_multi-task_rnn.py:265: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W1129 09:20:59.671189 140491425031936 module_wrapper.py:139] From run_multi-task_rnn.py:265: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# WARNING:tensorflow:From run_multi-task_rnn.py:269: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1129 09:20:59.671347 140491425031936 module_wrapper.py:139] From run_multi-task_rnn.py:269: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-29 09:20:59.671600: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-29 09:20:59.681815: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2099920000 Hz
# 2019-11-29 09:20:59.686187: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55868db6d7a0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-11-29 09:20:59.686226: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2019-11-29 09:20:59.689399: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-29 09:21:00.700644: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55868dc288a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2019-11-29 09:21:00.700677: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): TITAN Xp, Compute Capability 6.1
# 2019-11-29 09:21:00.701492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:82:00.0
# 2019-11-29 09:21:00.701621: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudart.so.10.0'; dlerror: libcudart.so.10.0: cannot open shared object file: No such file or directory
# 2019-11-29 09:21:00.701690: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10.0'; dlerror: libcublas.so.10.0: cannot open shared object file: No such file or directory
# 2019-11-29 09:21:00.701756: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcufft.so.10.0'; dlerror: libcufft.so.10.0: cannot open shared object file: No such file or directory
# 2019-11-29 09:21:00.701820: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcurand.so.10.0'; dlerror: libcurand.so.10.0: cannot open shared object file: No such file or directory
# 2019-11-29 09:21:00.701887: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusolver.so.10.0'; dlerror: libcusolver.so.10.0: cannot open shared object file: No such file or directory
# 2019-11-29 09:21:00.701950: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusparse.so.10.0'; dlerror: libcusparse.so.10.0: cannot open shared object file: No such file or directory
# 2019-11-29 09:21:00.704970: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-11-29 09:21:00.704988: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1641] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2019-11-29 09:21:00.705015: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-11-29 09:21:00.705025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-11-29 09:21:00.705035: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# Max sequence length:  [(50, 50)]
# Creating 1 layers of 128 units.
# WARNING:tensorflow:From run_multi-task_rnn.py:193: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1129 09:21:00.707659 140491425031936 module_wrapper.py:139] From run_multi-task_rnn.py:193: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:71: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# W1129 09:21:00.711405 140491425031936 deprecation.py:323] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:71: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:72: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# W1129 09:21:00.712150 140491425031936 deprecation.py:323] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:72: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:89: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1129 09:21:00.716734 140491425031936 module_wrapper.py:139] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:89: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# buckets [(50, 50)]
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:167: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W1129 09:21:00.786297 140491425031936 module_wrapper.py:139] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:167: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:178: static_bidirectional_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell, unroll=True))`, which is equivalent to this API
# W1129 09:21:00.876886 140491425031936 deprecation.py:323] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:178: static_bidirectional_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell, unroll=True))`, which is equivalent to this API
# WARNING:tensorflow:From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn.py:1610: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# W1129 09:21:00.877156 140491425031936 deprecation.py:323] From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn.py:1610: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# W1129 09:21:00.912659 140491425031936 deprecation.py:323] From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W1129 09:21:00.919532 140491425031936 deprecation.py:506] From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1129 09:21:00.949152 140491425031936 deprecation.py:323] From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# all_inputs 150
# Use the attention RNN model
# hidden Tensor("model/model_with_buckets/decoder_sequence_output/attention_RNN/Reshape_50:0", shape=(?, 50, 1, 256), dtype=float32)
# WARNING:tensorflow:From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/rnn/python/ops/core_rnn_cell.py:183: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W1129 09:21:06.551157 140491425031936 deprecation.py:506] From /home/administrator5/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/rnn/python/ops/core_rnn_cell.py:183: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/seq_labeling.py:157: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# W1129 09:21:06.584095 140491425031936 module_wrapper.py:139] From /home/administrator5/ZDY/rnn-nlu-master/seq_labeling.py:157: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/seq_labeling.py:259: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1129 09:21:07.141483 140491425031936 deprecation.py:323] From /home/administrator5/ZDY/rnn-nlu-master/seq_labeling.py:259: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# initial_state Tensor("model/generate_seq_output/concat_52:0", shape=(?, 512), dtype=float32)
# attention_states Tensor("model/generate_seq_output/concat_53:0", shape=(?, 50, 256), dtype=float32)
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:140: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# W1129 09:21:07.399376 140491425031936 module_wrapper.py:139] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:140: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:142: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W1129 09:21:07.399578 140491425031936 module_wrapper.py:139] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:142: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:159: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W1129 09:21:23.259254 140491425031936 module_wrapper.py:139] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:159: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:159: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1129 09:21:23.259500 140491425031936 module_wrapper.py:139] From /home/administrator5/ZDY/rnn-nlu-master/multi_task_model.py:159: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# buckets [(50, 50)]
# all_inputs 150
# Use the attention RNN model
# hidden Tensor("model_1/model_with_buckets/decoder_sequence_output/attention_RNN/Reshape_50:0", shape=(?, 50, 1, 256), dtype=float32)
# initial_state Tensor("model_1/generate_seq_output/concat_52:0", shape=(?, 512), dtype=float32)
# attention_states Tensor("model_1/generate_seq_output/concat_53:0", shape=(?, 50, 256), dtype=float32)
# Reading model parameters from model_tmp/model.ckpt-30000
# INFO:tensorflow:Restoring parameters from model_tmp/model.ckpt-30000
# I1129 09:21:28.199663 140491425031936 saver.py:1284] Restoring parameters from model_tmp/model.ckpt-30000
# Creating model with source_vocab_size=42, target_vocab_size=15, label_vocab_size=3.
# Reading train/valid/test data (training set limit: 0).
# WARNING:tensorflow:From run_multi-task_rnn.py:157: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1129 09:21:30.134637 140491425031936 module_wrapper.py:139] From run_multi-task_rnn.py:157: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
